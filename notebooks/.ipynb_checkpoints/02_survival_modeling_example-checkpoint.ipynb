# %% [markdown]
# # Survival Modeling Example
#
# This notebook demonstrates an educational survival workflow using the merged cohort CSV. If your dataset does not have survival columns, it can add **synthetic demo outcomes** for learning purposes.

# %%
import pandas as pd
from ehr_fhir_genomics_toolkit.survival import add_demo_survival_outcomes, fit_cox_example

DATA_PATH = '../demo_sclc_dataset.csv'  # update as needed
df = pd.read_csv(DATA_PATH)
df.head()
# Out:
#   sample_id patient_id               diagnosis  age_at_collection  \
# 0    S00001      P0001  small cell lung cancer                 79
# 1    S00002      P0001  small cell lung cancer                 68
# 2    S00003      P0002  small cell lung cancer                 70
# 3    S00004      P0002  small cell lung cancer                 78
# 4    S00005      P0003  small cell lung cancer                 66
#
#   collection_date     ASCL1      CHGA      DLL3     GFI1B     INSM1  ...  \
# 0      2019-01-15 -0.124765 -0.741219 -0.305298 -0.842274  0.209516  ...
# 1      2019-01-29  0.680677 -1.358840 -0.472242  0.584151 -1.304164  ...
# 2      2019-02-12  0.089059 -1.554386 -0.502004 -1.002770 -0.833088  ...
# 3      2019-02-26 -1.193165  0.108031  1.390714 -1.515254  0.891274  ...
# 4      2019-03-12  2.774938  3.508703  4.279978 -0.334207  0.544594  ...
#
#         VIM     WWTR1      YAP1  SCLC_A_ASCL1  SCLC_N_NEUROD1  SCLC_P_POU2F3  \
# 0  3.006260  2.754787  1.718905     -0.390427        0.409334      -0.181964
# 1  0.142125 -0.201557 -2.531386     -0.383468       -1.480866       1.863691
# 2  1.892149  2.364048  2.586214     -0.655777        0.048929      -0.324805
# 3  1.332602  2.606407  3.108580      0.101860        1.024942      -0.443561
# 4  0.145259  1.240219  1.486677      3.521206       -0.140999      -0.034443
#
#    SCLC_Y_YAP1  mut_TP53  mut_RB1  mut_MYC
# 0     2.493317       1.0      1.0      1.0
# 1    -0.863606       1.0      1.0      0.0
# 2     2.280803       1.0      1.0      1.0
# 3     2.349197       0.0      1.0      0.0
# 4     0.957385       1.0      1.0      1.0
#
# [5 rows x 24 columns]

# %%
if {'survival_time_months','event_observed'} - set(df.columns):
    df = add_demo_survival_outcomes(df, seed=7)
df[['survival_time_months','event_observed']].head()
# Out:
#    survival_time_months  event_observed
# 0                  3.78               1
# 1                 10.43               1
# 2                  3.25               1
# 3                  7.71               1
# 4                  1.16               1

# %%
cph = fit_cox_example(df)
cph.summary
# Out:
#                     coef  exp(coef)  se(coef)  coef lower 95%  coef upper 95%  \
# covariate
# SCLC_A_ASCL1    0.101890   1.107262  0.138823       -0.170199        0.373979
# SCLC_N_NEUROD1  0.154698   1.167306  0.181368       -0.200776        0.510173
# SCLC_P_POU2F3  -0.213867   0.807456  0.195699       -0.597431        0.169697
# SCLC_Y_YAP1     0.250344   1.284467  0.161350       -0.065896        0.566584
# mut_TP53        1.019229   2.771057  0.436805        0.163106        1.875352
# mut_RB1         0.862765   2.369703  0.393394        0.091726        1.633803
# mut_MYC         0.331042   1.392419  0.337937       -0.331303        0.993387
#
#                 exp(coef) lower 95%  exp(coef) upper 95%  cmp to         z  \
# covariate
# SCLC_A_ASCL1               0.843497             1.453507     0.0  0.733957
# SCLC_N_NEUROD1             0.818095             1.665579     0.0  0.852953
# SCLC_P_POU2F3              0.550224             1.184946     0.0 -1.092833
# SCLC_Y_YAP1                0.936228             1.762236     0.0  1.551560
# mut_TP53                   1.177162             6.523114     0.0  2.333371
# mut_RB1                    1.096065             5.123320     0.0  2.193131
# mut_MYC                    0.717988             2.700366     0.0  0.979597
#
#                        p  -log2(p)
# covariate
# SCLC_A_ASCL1    0.462975  1.110994
# SCLC_N_NEUROD1  0.393686  1.344884
# SCLC_P_POU2F3   0.274467  1.865296
# SCLC_Y_YAP1     0.120768  3.049696
# mut_TP53        0.019629  5.670892
# mut_RB1         0.028298  5.143158
# mut_MYC         0.327285  1.611381
