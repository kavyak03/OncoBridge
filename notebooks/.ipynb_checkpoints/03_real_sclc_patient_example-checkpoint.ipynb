# %% [markdown]
# # Real SCLC Patient Example Walkthrough
#
# This notebook walks through the **included real-patient SCLC example** derived from the attached TumorMiner-style files.
#
# It assumes you already have 'sclc_real_patient_panel_dataset.csv' from the real dataset ingestion and analysis dataset creation from steps provided in the README.
#
# This notebook focuses on: cohort overview, real patient metadata fields, expression signature summaries, mutation summaries, optional coarse prior-treatment label exploration, and survival outcome exploration when available in the metadata.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

DATA_PATH = Path('../sclc_real_patient_panel_dataset.csv')

if not DATA_PATH.exists():
    raise FileNotFoundError('Expected ../sclc_real_patient_panel_dataset.csv. Run the preparation + CLI steps first.')
    
df = pd.read_csv(DATA_PATH)
print(df.shape)
df.head()
# Out:
# (190, 26)
#   sample_id patient_id               diagnosis  age_at_collection  \
# 0    S00022     S00022  small cell lung cancer                 47
# 1   S00035T     S00035  small cell lung cancer                 65
# 2    S00213     S00213  small cell lung cancer                 65
# 3    S00356     S00356  small cell lung cancer                 54
# 4    S00825     S00825  small cell lung cancer                 59
#
#   collection_date  regimen  line_of_therapy     ASCL1      CHGA      DLL3  \
# 0      2020-01-01     none                1  7.497582  7.725421  5.340433
# 1      2020-01-01     none                1  9.182920  6.358987  5.587413
# 2      2020-01-01  unknown                1  7.611717  5.784224  6.204977
# 3      2020-01-01     none                1  6.385187  6.266899  4.541429
# 4      2020-01-01     none                1  7.665465  7.600822  3.587413
#
#    ...       VIM     WWTR1      YAP1  SCLC_A_ASCL1  SCLC_N_NEUROD1  \
# 0  ...  6.536825  2.895106  2.490542      6.854479        4.861725
# 1  ...  8.051630  2.880577  3.208479      7.043107        3.569385
# 2  ...  8.123005  2.802575  3.470504      6.533639        4.760580
# 3  ...  7.741016  3.588635  3.743175      5.731171        3.490248
# 4  ...  8.426100  4.397777  4.303571      6.284567        3.351572
#
#    SCLC_P_POU2F3  SCLC_Y_YAP1  mut_TP53  mut_RB1  mut_MYC
# 0       0.045948     3.974158       NaN      NaN      NaN
# 1       0.104658     4.713562       NaN      NaN      NaN
# 2       0.043032     4.798695       NaN      NaN      NaN
# 3       0.246955     5.024275       NaN      NaN      NaN
# 4       0.264597     5.709149       NaN      NaN      NaN
#
# [5 rows x 26 columns]

# %%
print('Columns:')

for c in df.columns:
    print('-', c)
# Out:
# Columns:
# - sample_id
# - patient_id
# - diagnosis
# - age_at_collection
# - collection_date
# - regimen
# - line_of_therapy
# - ASCL1
# - CHGA
# - DLL3
# - GFI1B
# - INSM1
# - NEUROD1
# - POU2F3
# - SYP
# - TRPM5
# - VIM
# - WWTR1
# - YAP1
# - SCLC_A_ASCL1
# - SCLC_N_NEUROD1
# - SCLC_P_POU2F3
# - SCLC_Y_YAP1
# - mut_TP53
# - mut_RB1
# - mut_MYC

# %% [markdown]
# ## Cohort overview

# %%
overview_cols = [c for c in ['sample_id','patient_id','diagnosis','age_at_collection','collection_date','sample_type','biopsy_site','tumor_stage','gender','vital_status','prior_treatment_label'] if c in df.columns]
df[overview_cols].head(10)
# Out:
#   sample_id patient_id               diagnosis  age_at_collection  \
# 0    S00022     S00022  small cell lung cancer                 47
# 1   S00035T     S00035  small cell lung cancer                 65
# 2    S00213     S00213  small cell lung cancer                 65
# 3    S00356     S00356  small cell lung cancer                 54
# 4    S00825     S00825  small cell lung cancer                 59
# 5    S00829     S00829  small cell lung cancer                 63
# 6    S00831     S00831  small cell lung cancer                 63
# 7    S00832     S00832  small cell lung cancer                 70
# 8    S00838     S00838  small cell lung cancer                 73
# 9    S01242     S01242  small cell lung cancer                 76
#
#   collection_date
# 0      2020-01-01
# 1      2020-01-01
# 2      2020-01-01
# 3      2020-01-01
# 4      2020-01-01
# 5      2020-01-01
# 6      2020-01-01
# 7      2020-01-01
# 8      2020-01-01
# 9      2020-01-01

# %%
if 'sample_type' in df.columns:
    df['sample_type'].value_counts(dropna=False)

# %%
if 'biopsy_site' in df.columns:
    df['biopsy_site'].value_counts(dropna=False).head(15)

# %% [markdown]
# ## Signature summaries

# %%
sig_cols = [c for c in df.columns if c.startswith('SCLC_')]
sig_cols
# Out:
# ['SCLC_A_ASCL1', 'SCLC_N_NEUROD1', 'SCLC_P_POU2F3', 'SCLC_Y_YAP1']

# %%
if sig_cols:
    df[sig_cols].describe().T

# %%
if sig_cols:
    for col in sig_cols:
        plt.figure(figsize=(6,4))
        pd.to_numeric(df[col], errors='coerce').hist()
        plt.title(col)
        plt.xlabel('score')
        plt.ylabel('count')
        plt.show()

# %% [markdown]
# ## Mutation summaries

# %%
mut_cols = [c for c in df.columns if c.startswith('mut_')]
mut_cols
# Out:
# ['mut_TP53', 'mut_RB1', 'mut_MYC']

# %%
if mut_cols:
    mut_summary = df[mut_cols].apply(pd.to_numeric, errors='coerce').fillna(0).sum().sort_values(ascending=False)
mut_summary
# Out:
# mut_TP53    23.0
# mut_RB1     16.0
# mut_MYC      0.0
# dtype: float64

# %% [markdown]
# ## Coarse prior-treatment / therapy view
#
# This dataset does **not** contain regimen-level therapy lines from the source bundle. `regimen` here is derived from the metadata's coarse prior-treatment label and should be interpreted cautiously.

# %%
for therapy_col in ['regimen', 'prior_treatment_label']:
    if therapy_col in df.columns:
        print(f'Value counts for {therapy_col}:')
        print(df[therapy_col].value_counts(dropna=False))
# Out:
# Value counts for regimen:
# regimen
# none                  81
# chemotherapy          73
# combinationtherapy    32
# unknown                4
# Name: count, dtype: int64

# %%
if 'regimen' in df.columns and sig_cols:
    group = df.groupby('regimen', dropna=False)[sig_cols].mean(numeric_only=True)
group
# Out:
#                     SCLC_A_ASCL1  SCLC_N_NEUROD1  SCLC_P_POU2F3  SCLC_Y_YAP1
# regimen
# chemotherapy            4.183488        2.957282       0.501933     4.185286
# combinationtherapy      5.003137        3.896918       0.127857     4.562668
# none                    4.616229        3.643025       1.047129     4.983479
# unknown                 6.317309        4.588525       0.135362     4.258903

# %% [markdown]
# ## Survival metadata exploration
#
# The included real metadata contains fields like `os_months` and `event_observed` when available. This is metadata exploration only; no synthetic survival augmentation is added in this notebook.

# %%
surv_cols = [c for c in ['os_months','event_observed','vital_status'] if c in df.columns]
surv_cols
# Out:
# []

# %%
if 'os_months' in df.columns:
    pd.to_numeric(df['os_months'], errors='coerce').describe()

# %%
if 'os_months' in df.columns:
    plt.figure(figsize=(6,4))
    pd.to_numeric(df['os_months'], errors='coerce').dropna().hist()
    plt.title('Overall survival months (metadata field)')
    plt.xlabel('months')
    plt.ylabel('count')
    plt.show()

# %% [markdown]
# ## Simple cross-tabs

# %%
if 'sample_type' in df.columns and 'mut_TP53' in df.columns:
    pd.crosstab(df['sample_type'], df['mut_TP53'], dropna=False)

# %%
if 'biopsy_site' in df.columns and sig_cols:
    df.groupby('biopsy_site', dropna=False)[sig_cols].mean(numeric_only=True).head(10)

# %% [markdown]
# ## Notes
#
# This is a **real-patient example** built from the attached SCLC source files. The expression matrix here is a **panel subset** chosen to align with the toolkit's example signatures and mutation features. The therapy file is **coarse** and derived from `priorTreatment`, not a regimen-level therapy table. Other real data sources can be used as long as they are transformed into the repo's default CSV ingestion format.
